# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Ls = [10] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'all' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], corrs[0][:end], errs[0][:end],
                 fmt='.-', label='Horizontal')
    plt.errorbar(Rs[i][:end], corrs[1][:end], errs[1][:end],
                 fmt='.-', label='Vertical')

plt.title('Correlations along spin direction', fontsize=14)
plt.xlabel('r', fontsize=10)
plt.ylabel('$<s_0 s_r>$', fontsize=10)
# plt.xscale('log')
# plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_testsamedir'))
plt.show()

# %%
Ls = [10] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'all' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], corrs[2][:end], errs[2][:end],
                 fmt='.-', label='Horizontal')
    plt.errorbar(Rs[i][:end], corrs[3][:end], errs[3][:end],
                 fmt='.-', label='Vertical')

plt.title('Correlations perpendicular to spin direction', fontsize=14)
plt.xlabel('r', fontsize=10)
plt.ylabel('$<s_0 s_r>$', fontsize=10)
# plt.xscale('log')
# plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_testperpdir'))
plt.show()

# %%
Ls = [10] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'all' # all, final

Rs = [np.arange(1, 2*L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][1:end:2], corrs[4][1:end:2], errs[4][1:end:2],
                 fmt='.-', label='Diagonal       (same dir)')
    plt.errorbar(Rs[i][1:end:2], corrs[5][1:end:2], errs[5][1:end:2],
                 fmt='.-', label='Antidiagonal (same dir)')

plt.title('Correlations along diagonals', fontsize=14)
plt.xlabel('r', fontsize=10)
plt.ylabel('$<s_0 s_r>$', fontsize=10)
# plt.xscale('log')
# plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_testdiagsamedir'))
plt.show()

# %%
Ls = [10] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'all' # all, final

Rs = [np.arange(1, 2*L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end:2], corrs[4][:end:2], errs[4][:end:2],
                 fmt='.-', label='Diagonal       (perp. dir)')
    plt.errorbar(Rs[i][:end:2], corrs[5][:end:2], errs[5][:end:2],
                 fmt='.-', label='Antidiagonal (perp. dir)')

plt.title('Correlations along diagonals', fontsize=14)
plt.xlabel('r', fontsize=10)
plt.ylabel('$<s_0 s_r>$', fontsize=10)
# plt.xscale('log')
# plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_testdiagperpdir'))
plt.show()

# %%
Ls = [10] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt='.-', label='Spin direction')
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt='.-', label='Perpendicular')
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt='.-', label='Diagonals (same dir)')
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt='.-', label='Diagonals (perp. dir)')

plt.title('%s x %s, #iter: %s' % (Ls[0], Ls[0], Niter), fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_all'))
plt.show()

# %%
Ls = [20] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt='.-', label='Spin direction')
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt='.-', label='Perpendicular')
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt='.-', label='Diagonals (same dir)')
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt='.-', label='Diagonals (perp. dir)')

plt.title('%s x %s, #iter: %s' % (Ls[0], Ls[0], Niter), fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_all'))
plt.show()

# %%
Ls = [30] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt='.-', label='Spin direction')
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt='.-', label='Perpendicular')
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt='.-', label='Diagonals (same dir)')
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt='.-', label='Diagonals (perp. dir)')

plt.title('%s x %s, #iter: %s' % (Ls[0], Ls[0], Niter), fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_all'))
plt.show()

# %%
Ls = [40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt='.-', label='Spin direction')
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt='.-', label='Perpendicular')
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt='.-', label='Diagonals (same dir)')
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt='.-', label='Diagonals (perp. dir)')

plt.title('%s x %s, #iter: %s' % (Ls[0], Ls[0], Niter), fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/L%s_N%s_%sx%sbins%s.png' % (Ls[0], Niter, Ni, Nbins, '_all'))
plt.show()

# %%
Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt='.-', label='%s x %s' % (L, L))

plt.title('Along spin direction, #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('all', Niter, Ni, Nbins, '_samedir'))
plt.show()

# %%
Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt='.-', label='%s x %s' % (L, L))

plt.title('Perpendicular to spin direction, #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('all', Niter, Ni, Nbins, '_perpdir'))
plt.show()

# %%
Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt='.-', label='%s x %s' % (L, L))

plt.title('Diagonals (same-direction spins), #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('all', Niter, Ni, Nbins, '_diagsamedir'))
plt.show()

# %%
Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = None

plt.figure(dpi=144)
for i, L in enumerate(Ls):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt='.-', label='%s x %s' % (L, L))

plt.title('Diagonals (perpendicular-direction spins), #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('all', Niter, Ni, Nbins, '_diagperpdir'))
plt.show()

# %%
fit = lambda x, a, b: -a * x + b

Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = Ls[-1] // 3 # plot endpoint
endfits = (4, 5, 6, 7) # fit endpoint
colors = 'rgyb' # colors for each L

plt.figure(dpi=144)
for i, L, endfit, color in zip(range(len(Ls)), Ls, endfits, colors):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[0][:end]), errs[0][:end],
                 fmt=color+'.', label='%s x %s' % (L, L))
    
    # least-squares fit
    pars, pars_cov = optimize.curve_fit(fit, np.log(Rs[i][1:endfit]),
                                        np.log(np.abs(corrs[0][1:endfit])), p0=(1/3, 0),
                                        sigma = errs[0][1:endfit] / np.abs(corrs[0][1:endfit]))
    print('L%i : \ta : %.3f +- %.3f,\tb : %.3f +- %.3f' %
          (L, pars[0], np.sqrt(np.diag(pars_cov))[0], pars[1], np.sqrt(np.diag(pars_cov))[1]))

    r = np.log(np.linspace(2, Rs[i][endfit-1], 100))
    plt.plot(np.exp(r), np.exp(fit(r, *pars)), color+'-', linewidth=1., label='fit: %s x %s' % (L, L))

plt.title('Along spin direction, #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('allfit', Niter, Ni, Nbins, '_samedir'))
plt.show()
# Out:
# L10 : 	a : 1.603 +- 0.118,	b : -1.212 +- 0.106
# L20 : 	a : 2.003 +- 0.070,	b : -1.006 +- 0.068
# L30 : 	a : 2.112 +- 0.046,	b : -0.939 +- 0.042
# L40 : 	a : 2.132 +- 0.047,	b : -0.919 +- 0.041

# %%
fit = lambda x, a, b: -a * x + b

Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rs = [np.arange(1, L) for L in Ls]
end = Ls[-1] // 3 # plot endpoint
endfits = (4, 5, 6, 6) # fit endpoint
colors = 'rgyb' # colors for each L

plt.figure(dpi=144)
for i, L, endfit, color in zip(range(len(Ls)), Ls, endfits, colors):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rs[i][:end], np.abs(corrs[1][:end]), errs[1][:end],
                 fmt=color+'.', label='%s x %s' % (L, L))
    
    # least-squares fit
    pars, pars_cov = optimize.curve_fit(fit, np.log(Rs[i][1:endfit]),
                                        np.log(np.abs(corrs[1][1:endfit])), p0=(1/3, 0),
                                        sigma = errs[1][1:endfit] / np.abs(corrs[1][1:endfit]))
    print('L%i : \ta : %.3f +- %.3f,\tb : %.3f +- %.3f' %
          (L, pars[0], np.sqrt(np.diag(pars_cov))[0], pars[1], np.sqrt(np.diag(pars_cov))[1]))

    r = np.log(np.linspace(2, Rs[i][endfit-1], 100))
    plt.plot(np.exp(r), np.exp(fit(r, *pars)), color+'-', linewidth=1., label='fit: %s x %s' % (L, L))

plt.title('Perpendicular to spin direction, #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('allfit', Niter, Ni, Nbins, '_perpdir'))
plt.show()
# Out:
# L10 : 	a : 2.213 +- 0.062,	b : -1.035 +- 0.050
# L20 : 	a : 2.035 +- 0.106,	b : -1.112 +- 0.088
# L30 : 	a : 1.969 +- 0.103,	b : -1.137 +- 0.095
# L40 : 	a : 1.987 +- 0.112,	b : -1.115 +- 0.106

# %%
fit = lambda x, a, b: -a * x + b

Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = Ls[-1] // 3 # plot endpoint
endfits = (5, 5, 4, 4) # fit endpoint
colors = 'rgyb' # colors for each L

plt.figure(dpi=144)
for i, L, endfit, color in zip(range(len(Ls)), Ls, endfits, colors):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rsd[i][1:end:2], np.abs(corrs[2][1:end:2]), errs[2][1:end:2],
                 fmt=color+'.', label='%s x %s' % (L, L))
    
    # least-squares fit
    pars, pars_cov = optimize.curve_fit(fit, np.log(Rsd[i][1:end:2][1:endfit]),
                                        np.log(np.abs(corrs[2][1:end:2][1:endfit])), p0=(2, 0),
                               sigma = errs[2][1:end:2][1:endfit] / np.abs(corrs[2][1:end:2][1:endfit]))
    print('L%i : \ta : %.3f +- %.3f,\tb : %.3f +- %.3f' %
          (L, pars[0], np.sqrt(np.diag(pars_cov))[0], pars[1], np.sqrt(np.diag(pars_cov))[1]))

    r = np.log(np.linspace(Rsd[i][3], Rsd[i][1:end:2][endfit-1], 100))
    plt.plot(np.exp(r), np.exp(fit(r, *pars)), color+'-', linewidth=1., label='fit: %s x %s' % (L, L))

plt.title('Diagonals (same-direction spins), #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('allfit', Niter, Ni, Nbins, '_diagsamedir'))
plt.show()
# Out:
# L10 : 	a : 0.268 +- 0.062,	b : -4.159 +- 0.093
# L20 : 	a : 0.598 +- 0.097,	b : -4.552 +- 0.153
# L30 : 	a : 0.822 +- 0.213,	b : -4.582 +- 0.268
# L40 : 	a : 1.020 +- 0.348,	b : -4.665 +- 0.460

# %%
fit = lambda x, a, b: -a * x + b

Ls = [10, 20, 30, 40] # [10, 20, 30, 40]
Ni = 1000
Nbins = 20
Niter = Ni * Nbins
corr_type = 'final' # all, final

Rsd = [np.sqrt(1/2) * np.arange(1, 2*L) for L in Ls] # diagonal
end = Ls[-1] // 2 + 2 # plot endpoint
endfits = (4, 5, 5, 7) # fit endpoint
colors = 'rgyb' # colors for each L

plt.figure(dpi=144)
for i, L, endfit, color in zip(range(len(Ls)), Ls, endfits, colors):
    data = np.load('data/L%s_N%s_%sx%sbins_%s.npz' % (L, Niter, Ni, Nbins, corr_type))
    corrs, errs = data['corrs'], data['errs']
    
    plt.errorbar(Rsd[i][:end:2], np.abs(corrs[2][:end:2]), errs[2][:end:2],
                 fmt=color+'.', label='%s x %s' % (L, L))
    
    # least-squares fit
    pars, pars_cov = optimize.curve_fit(fit, np.log(Rsd[i][:end:2][1:endfit]),
                                        np.log(np.abs(corrs[2][:end:2][1:endfit])), p0=(2, 0),
                               sigma = errs[2][:end:2][1:endfit] / np.abs(corrs[2][:end:2][1:endfit]))
    print('L%i : \ta : %.3f +- %.3f,\tb : %.3f +- %.3f' %
          (L, pars[0], np.sqrt(np.diag(pars_cov))[0], pars[1], np.sqrt(np.diag(pars_cov))[1]))

    r = np.log(np.linspace(Rsd[i][2], Rsd[i][:end:2][endfit-1], 100))
    plt.plot(np.exp(r), np.exp(fit(r, *pars)), color+'-', linewidth=1., label='fit: %s x %s' % (L, L))

plt.title('Diagonals (perpendicular-direction spins), #iter: %s' % Niter, fontsize=14)
plt.xlabel('$\log(r)$', fontsize=10)
plt.ylabel('$\log \ |<s_0 s_r>|$', fontsize=10)
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.savefig('plots/%s_N%s_%sx%sbins%s.png' % ('allfit', Niter, Ni, Nbins, '_diagperpdir'))
plt.show()
# Out:
# L10 : 	a : 2.344 +- 0.237,	b : -0.991 +- 0.200
# L20 : 	a : 1.974 +- 0.035,	b : -1.241 +- 0.030
# L30 : 	a : 1.921 +- 0.016,	b : -1.285 +- 0.015
# L40 : 	a : 1.960 +- 0.015,	b : -1.262 +- 0.015
